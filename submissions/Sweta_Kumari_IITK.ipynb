# %% [markdown]
# # K-Nearest-Neighbors (KNN)
#
#
# ## Importing Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# #Importing the data
# ## About the data
#
# <img src='https://images.squarespace-cdn.com/content/v1/5c36736d9d5abb8b44c6b7f7/1586468701075-G14EXPZE2VNMJFKDCQ0T/rook+and+king+logo.jpg?format=500w' align="center"><br>
#   Chess End-Game -- King+Rook versus King+Pawn on a7
#   (usually abbreviated KRKPA7).  The pawn on a7 means it is one square
#   away from queening.  It is the King+Rook's side (white) to move.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-221558da-a389-4149-9828-618e7443ac55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-221558da-a389-4149-9828-618e7443ac55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving King-RookvsKing-Pawn.xlsx to King-RookvsKing-Pawn.xlsx

# %%
king_data=pd.read_excel('King-RookvsKing-Pawn.xlsx')

# %%
king_data.head(10)
# Out:
#   Column1 Column2 Column3 Column4  ... Column34 Column35 Column36 Column37
# 0       f       f       f       f  ...        t        t        n      won
# 1       f       f       f       f  ...        t        t        n      won
# 2       f       f       f       f  ...        t        t        n      won
# 3       f       f       f       f  ...        t        t        n      won
# 4       f       f       f       f  ...        t        t        n      won
# 5       f       f       f       f  ...        t        t        n      won
# 6       f       f       f       f  ...        t        t        n      won
# 7       f       f       f       f  ...        t        t        n      won
# 8       f       f       f       f  ...        t        t        n      won
# 9       f       f       f       f  ...        t        t        n      won
#
# [10 rows x 37 columns]

# %%
king_data.columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6',
#        'Column7', 'Column8', 'Column9', 'Column10', 'Column11', 'Column12',
#        'Column13', 'Column14', 'Column15', 'Column16', 'Column17', 'Column18',
#        'Column19', 'Column20', 'Column21', 'Column22', 'Column23', 'Column24',
#        'Column25', 'Column26', 'Column27', 'Column28', 'Column29', 'Column30',
#        'Column31', 'Column32', 'Column33', 'Column34', 'Column35', 'Column36',
#        'Column37'],
#       dtype='object')

# %%
object_col=['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6',
       'Column7', 'Column8', 'Column9', 'Column10', 'Column11', 'Column12',
       'Column13', 'Column14', 'Column15', 'Column16', 'Column17', 'Column18',
       'Column19', 'Column20', 'Column21', 'Column22', 'Column23', 'Column24',
       'Column25', 'Column26', 'Column27', 'Column28', 'Column29', 'Column30',
       'Column31', 'Column32', 'Column33', 'Column34', 'Column35', 'Column36'
       ]

# %% [markdown]
# Droping NaN values

# %%
king_data.dropna(axis=0)
# Out:
#      Column1 Column2 Column3 Column4  ... Column34 Column35 Column36 Column37
# 0          f       f       f       f  ...        t        t        n      won
# 1          f       f       f       f  ...        t        t        n      won
# 2          f       f       f       f  ...        t        t        n      won
# 3          f       f       f       f  ...        t        t        n      won
# 4          f       f       f       f  ...        t        t        n      won
# ...      ...     ...     ...     ...  ...      ...      ...      ...      ...
# 3191       t       f       f       f  ...        t        f        n    nowin
# 3192       t       f       f       f  ...        t        f        n    nowin
# 3193       t       f       f       f  ...        t        f        n    nowin
# 3194       t       f       t       f  ...        f        f        n    nowin
# 3195       t       f       t       f  ...        f        f        n    nowin
#
# [3196 rows x 37 columns]

# %%
print(f'{king_data.Column37.unique()}')
# Out:
# ['won' 'nowin']

# %%
king_data['Column37']=king_data['Column37'].apply({'won':2,'nowin':1}.get)

# %%
king_data.head(10)
# Out:
#   Column1 Column2 Column3 Column4  ... Column34 Column35 Column36 Column37
# 0       f       f       f       f  ...        t        t        n        2
# 1       f       f       f       f  ...        t        t        n        2
# 2       f       f       f       f  ...        t        t        n        2
# 3       f       f       f       f  ...        t        t        n        2
# 4       f       f       f       f  ...        t        t        n        2
# 5       f       f       f       f  ...        t        t        n        2
# 6       f       f       f       f  ...        t        t        n        2
# 7       f       f       f       f  ...        t        t        n        2
# 8       f       f       f       f  ...        t        t        n        2
# 9       f       f       f       f  ...        t        t        n        2
#
# [10 rows x 37 columns]

# %% [markdown]
# ## Spliting the data.

# %%
X=king_data.copy()
y=X.pop('Column37')

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.7,train_size=0.3)

# %%
y_test.head(10)
# Out:
# 1928    2
# 2379    1
# 1609    2
# 2272    2
# 420     2
# 2325    2
# 3130    1
# 2090    2
# 524     2
# 2396    1
# Name: Column37, dtype: int64

# %% [markdown]
# ## Training and predicting the model using KNN algo.

# %%
from sklearn.preprocessing import OneHotEncoder
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)

one_hot_train=pd.DataFrame(OH_encoder.fit_transform(X_train[object_col]))
one_hot_test=pd.DataFrame(OH_encoder.transform(X_test[object_col]))
one_hot_train.index = X_train.index
one_hot_test.index = X_test.index

# %%
num_X_train = X_train.drop(object_col, axis=1)
num_X_valid = X_test.drop(object_col, axis=1)

# %%
OH_X_train = pd.concat([num_X_train, one_hot_train], axis=1)
OH_X_valid = pd.concat([num_X_valid, one_hot_test], axis=1)

# %%
y_train.unique()
# Out:
# array([2, 1])

# %%
from sklearn.neighbors import KNeighborsClassifier as knn

model=knn(n_neighbors=1,
          leaf_size=1,
          algorithm='brute',
          weights='distance',
          p=1
          )

model.fit(OH_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='brute', leaf_size=1, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=1,
#                      weights='distance')

# %%
pred=model.predict(OH_X_valid)

# %% [markdown]
# ## Checking model accuracy.

# %%
from sklearn.metrics import accuracy_score

x=accuracy_score(y_test,pred)
print(f'the accuracy score is {x}')
# Out:
# the accuracy score is 0.8838248436103664

# %% [markdown]
# ## Using confusion matric

# %%
from sklearn.metrics import confusion_matrix

cm= confusion_matrix(y_test,pred)

# %%
print(cm)
# Out:
# [[ 902  170]
#  [  90 1076]]

# %% [markdown]
# **Ensemble Method - Extremely Randomized Trees**

# %% [markdown]
# Using averaging method, extremely randomized trees to increase the accuracy of the model.

# %%
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_estimators=10, max_depth=None,min_samples_split=2, random_state=0)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(clf, OH_X_train, y_train, cv=5)

# %%
scores.mean()
# Out:
# 0.9801701570680628

# %% [markdown]
# **Further tuning hyperparameters to increase accuracy**

# %%
clf = ExtraTreesClassifier(n_estimators=50, max_depth=None ,min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None,
                            random_state=0)

# %%
scores = cross_val_score(clf, OH_X_train,y_train, cv=5)
scores.mean()
# Out:
# 0.9853839441535778

# %% [markdown]
# The model accuracy goes from 0.9801701570680628 to 0.9853839441535778 on tuning the hyperparamenter n_estimators and max_features.
